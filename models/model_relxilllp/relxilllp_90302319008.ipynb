# %% [markdown]
# # Phase-averaged and phase-resolved spectroscopy

# %% [markdown]
# ## Loading data and observation, setting pathes

# %% [markdown]
# 1. Import the necessary packages.

# %%
import pandas as pd
import sys
sys.path.append('../../')
from nustar_scripts.nu_class import np, plt, os, glob, NustarObservation, scan_phase_resolved_products
from nustar_scripts.pulsar_init import Nu_path, ObsList
from nustar_scripts.nu_pyxspec import Model, Xset, AllModels,  AllModels, xspec,fit_spectra, scan_containers_ph_res,  plot_ph_res_storage

import matplotlib
# %matplotlib inline
pd.set_option('display.max_columns', 500)

# %% [markdown]
# 2. Set `ObsID` and `NustarObservation` object.

# %%
ObsID = ObsList[3] 
nu_obs = NustarObservation(ObsID, nu_path=Nu_path)
ph_ave_folder = nu_obs.products_path+'/spe_and_lc'
ph_res_folder = nu_obs.products_path+'/phase_resolved'
# Out:
# ###
# Observation 90302319008 loaded successfully

# %% [markdown]
# 3. Set xspec settings/models

# %%
model_name = 'relxilllp'  #set the model name
AllModels.lmod('relxill', '/Users/sdbykov/work/xray_pulsars/sj0243_nu/python_for_nustar/relxill_model/') #set path to relxill model
calc_errors = True #whether to calculate errors on spectral parameters.  useful to turn off when doing a quick fit.

AllModels.clear()
Xset.parallel.error = 22

# %% [markdown]
# ## Phase-averaged spectra

# %% [markdown]
# 1. Run cell below to set up an xspec model. Adjust its parameters to your needs and run `fit_spectra` function in the next cell.
#
# The spectral results will be saved in the `xspec/{model name}/` folder in the `out{ObsID}/products/phase_resolved/` directory.

# %%
os.chdir(ph_ave_folder)

model = Model("constant*phabs*(bbodyrad+relxilllp)")
model.phabs.nH = '0.8 -1'

model.bbodyrad.kT = '1'
model.bbodyrad.norm = '1e3' # ,, 0.1, 0.2, 3, 4'

model.relxilllp.h = '5 -1'
model.relxilllp.a = '0 -1'
model.relxilllp.Incl = '15'
model.relxilllp.Incl.frozen = False
model.relxilllp.Rin = '70 0.1, 0, 0, 900, 900'
model.relxilllp.Rout = '=1.1*p8'
model.relxilllp.z = '0 -1'
model.relxilllp.gamma = '1.2  0.005 0.3 0.3 3 3'
model.relxilllp.logxi = '4'
model.relxilllp.Ecut = '20'
model.relxilllp.Ecut.frozen = False
model.relxilllp.refl_frac = '0.3'
model.relxilllp.fixReflFrac = '0'
model.relxilllp.Afe = '5 -1'
# Out:
#  *** loading RELXILL model (version 1.4.3) ***

# %%
mo_fid_pars = fit_spectra(model = model, model_name = model_name, prefix = ObsID, dataset='spe_and_lc', rewrite = True, calc_errors = calc_errors)
mo_fid_pars
# Out:
# deleted xspec/relxilllp/*90302319008_relxilllp* and xspec/relxilllp/xcm/*90302319008_relxilllp* files
# no storage found. fitting...
#  loaded spe_and_lcA_sr.pi and spe_and_lcB_sr.pi from /Users/sdbykov/work/xray_pulsars/nustar_sj0243/nustar_products/out90302319008/products/spe_and_lc
# fitting done
# skipping errors for: []
#     18     0.997438      0.99986    (-0.00120689,0.00121453)
#      3      1.04164      1.09702    (-0.0298115,0.0255689)
#      4      354.308      399.567    (-19.5687,25.6906)
#      7      13.6269      18.5226    (-2.24613,2.64959)
#      8      47.0324      55.3815    (-4.05701,4.29216)
#     11     0.752824     0.794715    (-0.0204523,0.0214378)
# Apparent non-monotonicity in statistic space detected.
# Current bracket values 3.3921, 3.42364
# and delta stat 0.481512, 2.75932
# but latest trial 3.42313 gives 2.78662
# Suggest that you check this result using the steppar command.
#     12      3.29819      3.40787    (-0.0688435,0.0408361)
# Apparent non-monotonicity in statistic space detected.
# Current bracket values 17.644, 17.9655
# and delta stat 0, 2.8927
# but latest trial 17.9554 gives 2.90768
# Suggest that you check this result using the steppar command.
#     14      17.3548      17.8048    (-0.289246,0.160765)
#     15    0.0849108     0.102617    (-0.00872569,0.00898014)
#     17     0.186113     0.189901    (-0.00184459,0.00194326)
# Fit done;  chi2 = 3224.4141237687127 for 2735 dof, chi2_red = 1.1789448350159828, H0 prob = 1.82633735e-10
# <Storage with 2 containers>
# <Storage with 2 containers>

# %% [markdown]
# ## Phase-resolved spectra

# %% [markdown]
# 1.  Set the model for the phase-resolved spectra in bins.  Usially it is the same model as for phase-averaged spectra, but with some parameters frozen.

# %%
os.chdir(ph_res_folder)

# %%
#try to restore the model for phase-average spectra
xspec.Xset.restore(f'{ph_ave_folder}/xspec/{model_name}/xcm/{ObsID}_{model_name}.xcm_model')

#free some of its parameters to phase-averaged values
model = AllModels(1)
model.bbodyrad.kT.frozen = True
model.bbodyrad.norm.frozen = True
model.relxilllp.logxi.frozen = True
model.relxilllp.Rin.frozen = True
model.relxilllp.Incl.frozen = True

# %% [markdown]
# 2. Run the cell to iterate over phase bins and fit the spectra.

# %%
for binnum in range(1,11):
    print(f'##################### bin number {binnum} #####################')
    binnum = str(binnum)
    bb_pars = fit_spectra(model = model, model_name = model_name, prefix = f'{ObsID}_bin{binnum}', dataset=f'phase_resolved_bin{binnum}', rewrite = True, calc_errors=calc_errors)
# Out:
# ##################### bin number 1 #####################
# deleted xspec/relxilllp/*90302319008_bin1_relxilllp* and xspec/relxilllp/xcm/*90302319008_bin1_relxilllp* files
# no storage found. fitting...
#  loaded phase_resolved_bin1A_sr.pi and phase_resolved_bin1B_sr.pi from /Users/sdbykov/work/xray_pulsars/nustar_sj0243/nustar_products/out90302319008/products/phase_resolved
# fitting done
# skipping errors for: []
#     18     0.992244      1.00039    (-0.00406698,0.00408295)
#     11     0.510661     0.562916    (-0.0263894,0.0258662)
#     14       13.459      14.0492    (-0.29117,0.299019)
#     15     0.148039     0.166182    (-0.00901197,0.0091308)
#     17     0.104292     0.107625    (-0.00165782,0.00167537)
# Fit done;  chi2 = 1760.3707691022496 for 1600 dof, chi2_red = 1.100231730688906, H0 prob = 0.002915536763
# <Storage with 2 containers>
# ##################### bin number 2 #####################
# deleted xspec/relxilllp/*90302319008_bin2_relxilllp* and xspec/relxilllp/xcm/*90302319008_bin2_relxilllp* files
# no storage found. fitting...
#  loaded phase_resolved_bin2A_sr.pi and phase_resolved_bin2B_sr.pi from /Users/sdbykov/work/xray_pulsars/nustar_sj0243/nustar_products/out90302319008/products/phase_resolved
# fitting done
# skipping errors for: []
#     18     0.995708      1.00355    (-0.00391331,0.0039284)
#     11     0.751975     0.793726    (-0.0210825,0.0206694)
#     14      16.2417      16.9514    (-0.349878,0.359802)
#     15     0.101306     0.116902    (-0.0077406,0.00785553)
#     17     0.152672     0.157196    (-0.00225297,0.00227118)
# Fit done;  chi2 = 1629.4964772509286 for 1654 dof, chi2_red = 0.9851852945894368, H0 prob = 0.6614968912
# <Storage with 2 containers>
# ##################### bin number 3 #####################
# deleted xspec/relxilllp/*90302319008_bin3_relxilllp* and xspec/relxilllp/xcm/*90302319008_bin3_relxilllp* files
# no storage found. fitting...
#  loaded phase_resolved_bin3A_sr.pi and phase_resolved_bin3B_sr.pi from /Users/sdbykov/work/xray_pulsars/nustar_sj0243/nustar_products/out90302319008/products/phase_resolved
# fitting done
# skipping errors for: []
#     18     0.991803     0.999375    (-0.00377886,0.00379289)
#     11     0.900688     0.936559    (-0.018079,0.017792)
#     14      18.0094      18.8004    (-0.389282,0.401697)
#     15    0.0804052    0.0944056    (-0.00695076,0.00704967)
#     17     0.207162      0.21295    (-0.002883,0.0029055)
# Fit done;  chi2 = 1707.2538399673217 for 1680 dof, chi2_red = 1.0162225237900724, H0 prob = 0.3159192731
# <Storage with 2 containers>
# ##################### bin number 4 #####################
# deleted xspec/relxilllp/*90302319008_bin4_relxilllp* and xspec/relxilllp/xcm/*90302319008_bin4_relxilllp* files
# no storage found. fitting...
#  loaded phase_resolved_bin4A_sr.pi and phase_resolved_bin4B_sr.pi from /Users/sdbykov/work/xray_pulsars/nustar_sj0243/nustar_products/out90302319008/products/phase_resolved
# fitting done
# skipping errors for: []
#     18     0.990643     0.998113    (-0.00372815,0.00374179)
#     11     0.810577     0.845869    (-0.0178032,0.0174887)
#     14      16.3449      16.9895    (-0.318199,0.326338)
#     15    0.0685218      0.08225    (-0.00681882,0.0069093)
#     17     0.210613     0.216234    (-0.00280076,0.00282082)
# Fit done;  chi2 = 1704.0230122024545 for 1680 dof, chi2_red = 1.0142994120252706, H0 prob = 0.3357956584
# <Storage with 2 containers>
# ##################### bin number 5 #####################
# deleted xspec/relxilllp/*90302319008_bin5_relxilllp* and xspec/relxilllp/xcm/*90302319008_bin5_relxilllp* files
# no storage found. fitting...
#  loaded phase_resolved_bin5A_sr.pi and phase_resolved_bin5B_sr.pi from /Users/sdbykov/work/xray_pulsars/nustar_sj0243/nustar_products/out90302319008/products/phase_resolved
# fitting done
# skipping errors for: []
#     18     0.994629      1.00249    (-0.00392209,0.00393718)
#     11     0.643679      0.68599    (-0.0213772,0.0209333)
#     14      15.7603      16.4175    (-0.324576,0.332621)
#     15    0.0963785     0.111398    (-0.00745949,0.00755973)
#     17     0.154539     0.158983    (-0.00221373,0.00223018)
# Fit done;  chi2 = 1729.9030966163505 for 1695 dof, chi2_red = 1.0205917974137761, H0 prob = 0.2719817631
# <Storage with 2 containers>
# ##################### bin number 6 #####################
# deleted xspec/relxilllp/*90302319008_bin6_relxilllp* and xspec/relxilllp/xcm/*90302319008_bin6_relxilllp* files
# no storage found. fitting...
#  loaded phase_resolved_bin6A_sr.pi and phase_resolved_bin6B_sr.pi from /Users/sdbykov/work/xray_pulsars/nustar_sj0243/nustar_products/out90302319008/products/phase_resolved
# fitting done
# skipping errors for: []
#     18     0.997276      1.00491    (-0.00381216,0.00382657)
#     11     0.801634     0.834601    (-0.0183818,0.0145858)
#     14      19.2185      20.0157    (-0.436724,0.360404)
#     15     0.084449    0.0974061    (-0.00645162,0.00650549)
#     17     0.203083     0.208551    (-0.00292443,0.00254299)
# Fit done;  chi2 = 1813.5960555634847 for 1756 dof, chi2_red = 1.0327995760612099, H0 prob = 0.1653565192
# <Storage with 2 containers>
# ##################### bin number 7 #####################
# deleted xspec/relxilllp/*90302319008_bin7_relxilllp* and xspec/relxilllp/xcm/*90302319008_bin7_relxilllp* files
# no storage found. fitting...
#  loaded phase_resolved_bin7A_sr.pi and phase_resolved_bin7B_sr.pi from /Users/sdbykov/work/xray_pulsars/nustar_sj0243/nustar_products/out90302319008/products/phase_resolved
# fitting done
# skipping errors for: []
#     18      0.99332      1.00081    (-0.00374429,0.00374295)
#     11     0.838236     0.871541    (-0.0186974,0.0146076)
#     14      19.0834      19.8897    (-0.439017,0.367317)
# Fit done;  chi2 = 1863.8821380664613 for 1753 dof, chi2_red = 1.0632527884007195, H0 prob = 0.03246358106
#     15    0.0681773    0.0809266    (-0.00631208,0.00643719)
#     17     0.240077     0.246629    (-0.00350086,0.00305119)
# <Storage with 2 containers>
# ##################### bin number 8 #####################
# deleted xspec/relxilllp/*90302319008_bin8_relxilllp* and xspec/relxilllp/xcm/*90302319008_bin8_relxilllp* files
# no storage found. fitting...
#  loaded phase_resolved_bin8A_sr.pi and phase_resolved_bin8B_sr.pi from /Users/sdbykov/work/xray_pulsars/nustar_sj0243/nustar_products/out90302319008/products/phase_resolved
# fitting done
# skipping errors for: []
#     18     0.995388      1.00285    (-0.00372244,0.00374305)
#     11     0.862755     0.890052    (-0.0137143,0.0135825)
#     14      19.7135      20.4245    (-0.351147,0.359865)
#     15    0.0615604    0.0737595    (-0.00607369,0.0061255)
# Fit done;  chi2 = 1707.3102996534644 for 1763 dof, chi2_red = 0.9684119680394012, H0 prob = 0.8255318459
#     17     0.259291      0.26548    (-0.00307861,0.00311023)
# <Storage with 2 containers>
# ##################### bin number 9 #####################
# deleted xspec/relxilllp/*90302319008_bin9_relxilllp* and xspec/relxilllp/xcm/*90302319008_bin9_relxilllp* files
# no storage found. fitting...
#  loaded phase_resolved_bin9A_sr.pi and phase_resolved_bin9B_sr.pi from /Users/sdbykov/work/xray_pulsars/nustar_sj0243/nustar_products/out90302319008/products/phase_resolved
# fitting done
# skipping errors for: []
#     18     0.991272     0.998695    (-0.00370146,0.0037219)
#     11     0.706472     0.741414    (-0.0176566,0.0172857)
#     14      17.2933      17.9535    (-0.326489,0.333672)
#     15    0.0642475    0.0768823    (-0.00627696,0.00635783)
#     17     0.233493     0.239476    (-0.002984,0.00299943)
# Fit done;  chi2 = 1889.5235015316284 for 1780 dof, chi2_red = 1.0615300570402406, H0 prob = 0.03511820611
# <Storage with 2 containers>
# ##################### bin number 10 #####################
# deleted xspec/relxilllp/*90302319008_bin10_relxilllp* and xspec/relxilllp/xcm/*90302319008_bin10_relxilllp* files
# no storage found. fitting...
#  loaded phase_resolved_bin10A_sr.pi and phase_resolved_bin10B_sr.pi from /Users/sdbykov/work/xray_pulsars/nustar_sj0243/nustar_products/out90302319008/products/phase_resolved
# fitting done
# skipping errors for: []
#     18     0.997186       1.0051    (-0.00394934,0.00396456)
#     11     0.503799     0.549671    (-0.0231681,0.0227042)
#     14      14.4855      15.0726    (-0.290097,0.297009)
#     15     0.111038     0.126289    (-0.00758148,0.00766991)
#     17     0.136826     0.140769    (-0.00196297,0.00197986)
# Fit done;  chi2 = 1851.4976544273932 for 1689 dof, chi2_red = 1.0962093868723464, H0 prob = 0.003241378205
# <Storage with 2 containers>

# %% [markdown]
# ## Plot  phase-resolved results

# %% [markdown]
# 1. Run the following cells to plot the results.

# %%
df_ph_res = scan_containers_ph_res(model_name)
df_ph_res
# Out:
#                      error_l  error_u  frozen       val
# comp      par phase
# bbodyrad  kT  0.05       0.0      0.0     1.0  1.074265
#               0.15       0.0      0.0     1.0  1.074265
#               0.25       0.0      0.0     1.0  1.074265
#               0.35       0.0      0.0     1.0  1.074265
#               0.45       0.0      0.0     1.0  1.074265
# ...                      ...      ...     ...       ...
# relxilllp z   0.55       0.0      0.0     1.0  0.000000
#               0.65       0.0      0.0     1.0  0.000000
#               0.75       0.0      0.0     1.0  0.000000
#               0.85       0.0      0.0     1.0  0.000000
#               0.95       0.0      0.0     1.0  0.000000
#
# [150 rows x 4 columns]

# %%
df_ph_res.loc[pd.IndexSlice['relxilllp','refl_frac',:]]
# Out:
#         error_l   error_u  frozen       val
# phase
# 0.05   0.146202  0.164161     0.0  0.155126
# 0.15   0.100951  0.116556     0.0  0.108697
# 0.25   0.080268  0.094336     0.0  0.087253
# 0.35   0.067889  0.081618     0.0  0.074709
# 0.45   0.095989  0.110988     0.0  0.103441
# 0.55   0.084987  0.098100     0.0  0.091514
# 0.65   0.068510  0.081259     0.0  0.074855
# 0.75   0.061957  0.074286     0.0  0.068094
# 0.85   0.064355  0.077037     0.0  0.070657
# 0.95   0.109875  0.125010     0.0  0.117401

# %%
os.chdir(ph_res_folder)
plot_ph_res_storage(df_ph_res, nu_obs, 'phase_resolved');

# %% [markdown]
# With `df_ph_res` data frame and functions used above  you can visualize the results and creates plots and tables.
