# %% [markdown]
# # Phase-averaged and phase-resolved spectroscopy

# %% [markdown]
# ## Loading data and observation, setting pathes

# %% [markdown]
# 1. Import the necessary packages.

# %%
import pandas as pd
import sys
sys.path.append('../../')
from nustar_scripts.nu_class import np, plt, os, glob, NustarObservation, scan_phase_resolved_products
from nustar_scripts.pulsar_init import Nu_path, ObsList
from nustar_scripts.nu_pyxspec import Model, Xset, AllModels,  AllModels, xspec,fit_spectra, scan_containers_ph_res,  plot_ph_res_storage

import matplotlib
# %matplotlib inline
pd.set_option('display.max_columns', 500)

# %% [markdown]
# 2. Set `ObsID` and `NustarObservation` object.

# %%
ObsID = ObsList[3] 
nu_obs = NustarObservation(ObsID, nu_path=Nu_path)
ph_ave_folder = nu_obs.products_path+'/spe_and_lc'
ph_res_folder = nu_obs.products_path+'/phase_resolved'
# Out:
# ###
# Observation 90302319008 loaded successfully

# %% [markdown]
# 3. Set xspec settings/models

# %%
model_name = 'relxilllp'  #set the model name
AllModels.lmod('relxill', '/Users/sdbykov/work/xray_pulsars/sj0243_nu/python_for_nustar/relxill_model/') #set path to relxill model
calc_errors = True #whether to calculate errors on spectral parameters.  useful to turn off when doing a quick fit.

AllModels.clear()
Xset.parallel.error = 22

# %% [markdown]
# ## Phase-averaged spectra

# %% [markdown]
# 1. Run cell below to set up an xspec model. Adjust its parameters to your needs and run `fit_spectra` function in the next cell.
#
# The spectral results will be saved in the `xspec/{model name}/` folder in the `out{ObsID}/products/phase_resolved/` directory.

# %%
os.chdir(ph_ave_folder)

model = Model("constant*phabs*(bbodyrad+relxilllp)")
model.phabs.nH = '0.8 -1'

model.bbodyrad.kT = '1'
model.bbodyrad.norm = '1e3' # ,, 0.1, 0.2, 3, 4'

model.relxilllp.h = '5 -1'
model.relxilllp.a = '0 -1'
model.relxilllp.Incl = '15'
model.relxilllp.Incl.frozen = False
model.relxilllp.Rin = '70 0.1, 0, 0, 900, 900'
model.relxilllp.Rout = '=1.1*p8'
model.relxilllp.z = '0 -1'
model.relxilllp.gamma = '1.2  0.005 0.3 0.3 3 3'
model.relxilllp.logxi = '4'
model.relxilllp.Ecut = '20'
model.relxilllp.Ecut.frozen = False
model.relxilllp.refl_frac = '0.3'
model.relxilllp.fixReflFrac = '0'
model.relxilllp.Afe = '5 -1'

# %%
mo_fid_pars = fit_spectra(model = model, model_name = model_name, prefix = ObsID, dataset='spe_and_lc', rewrite = True, calc_errors = calc_errors)
mo_fid_pars
# Out:
# deleted xspec/relxilllp/*90302319008_relxilllp* and xspec/relxilllp/xcm/*90302319008_relxilllp* files
# no storage found. fitting...
#  loaded spe_and_lcA_sr.pi and spe_and_lcB_sr.pi from /Users/sdbykov/work/xray_pulsars/nustar_sj0243/nustar_products/out90302319008/products/spe_and_lc
# fitting done
# skipping errors for: []
#     18     0.997438      0.99986    (-0.00120689,0.00121453)
#      3      1.04164      1.09702    (-0.0298115,0.0255689)
#      4      354.308      399.567    (-19.5687,25.6906)
#      7      13.6269      18.5226    (-2.24613,2.64959)
#      8      47.0324      55.3815    (-4.05701,4.29216)
#     11     0.752824     0.794715    (-0.0204523,0.0214378)
# Apparent non-monotonicity in statistic space detected.
# Current bracket values 3.3921, 3.42364
# and delta stat 0.481512, 2.75932
# but latest trial 3.42313 gives 2.78662
# Suggest that you check this result using the steppar command.
#     12      3.29819      3.40787    (-0.0688435,0.0408361)
# Apparent non-monotonicity in statistic space detected.
# Current bracket values 17.644, 17.9655
# and delta stat 0, 2.8927
# but latest trial 17.9554 gives 2.90768
# Suggest that you check this result using the steppar command.
#     14      17.3548      17.8048    (-0.289246,0.160765)
#     15    0.0849108     0.102617    (-0.00872569,0.00898014)
#     17     0.186113     0.189901    (-0.00184459,0.00194326)
# Fit done;  chi2 = 3224.4141237687127 for 2735 dof, chi2_red = 1.1789448350159828, H0 prob = 1.82633735e-10
# <Storage with 2 containers>
# <Storage with 2 containers>

# %% [markdown]
# ## Phase-resolved spectra

# %% [markdown]
# 1.  Set the model for the phase-resolved spectra in bins.  Usially it is the same model as for phase-averaged spectra, but with some parameters frozen.

# %%
os.chdir(ph_res_folder)

# %%
#try to restore the model for phase-average spectra
xspec.Xset.restore(f'{ph_ave_folder}/xspec/{model_name}/xcm/{ObsID}_{model_name}.xcm_model')

#free some of its parameters to phase-averaged values
model = AllModels(1)
model.bbodyrad.kT.frozen = True
model.bbodyrad.norm.frozen = True
model.relxilllp.logxi.frozen = True
model.relxilllp.Rin.frozen = True
model.relxilllp.Incl.frozen = True

# %% [markdown]
# 2. Run the cell to iterate over phase bins and fit the spectra.

# %%
for binnum in range(1,11):
    print(f'##################### bin number {binnum} #####################')
    binnum = str(binnum)
    bb_pars = fit_spectra(model = model, model_name = model_name, prefix = f'{ObsID}_bin{binnum}', dataset=f'phase_resolved_bin{binnum}', rewrite = True, calc_errors=calc_errors)
# Out:
# ##################### bin number 1 #####################
# deleted xspec/relxilllp/*90302319004_bin1_relxilllp* and xspec/relxilllp/xcm/*90302319004_bin1_relxilllp* files
# no storage found. fitting...
#  loaded phase_resolved_bin1A_sr.pi and phase_resolved_bin1B_sr.pi from /Users/sdbykov/work/xray_pulsars/nustar_sj0243/nustar_products/out90302319004/products/phase_resolved
# fitting done
# skipping errors for: []
#     18     0.968975     0.977528    (-0.00427118,0.00428222)
#     11      1.37665      1.41002    (-0.0166158,0.0167638)
#     14      21.7835      23.0466    (-0.618813,0.644374)
#     15     0.114328     0.134354    (-0.00990013,0.010126)
# Fit done;  chi2 = 1384.2918409966796 for 1377 dof, chi2_red = 1.0052954546090629, H0 prob = 0.4398289625
#     17     0.666132     0.694605    (-0.0140905,0.014382)
# <Storage with 2 containers>
# ##################### bin number 2 #####################
# deleted xspec/relxilllp/*90302319004_bin2_relxilllp* and xspec/relxilllp/xcm/*90302319004_bin2_relxilllp* files
# no storage found. fitting...
#  loaded phase_resolved_bin2A_sr.pi and phase_resolved_bin2B_sr.pi from /Users/sdbykov/work/xray_pulsars/nustar_sj0243/nustar_products/out90302319004/products/phase_resolved
# fitting done
# skipping errors for: []
#     18      0.96712     0.975616    (-0.00424086,0.00425539)
#     11      1.38275      1.41549    (-0.0162005,0.0165352)
# Fit done;  chi2 = 1392.4395620061541 for 1384 dof, chi2_red = 1.006097949426412, H0 prob = 0.43142297
#     14      21.2756      22.4586    (-0.580781,0.602232)
#     15     0.111061     0.130004    (-0.00916362,0.00977943)
#     17     0.778402     0.810891    (-0.0160628,0.0164266)
# <Storage with 2 containers>
# ##################### bin number 3 #####################
# deleted xspec/relxilllp/*90302319004_bin3_relxilllp* and xspec/relxilllp/xcm/*90302319004_bin3_relxilllp* files
# no storage found. fitting...
#  loaded phase_resolved_bin3A_sr.pi and phase_resolved_bin3B_sr.pi from /Users/sdbykov/work/xray_pulsars/nustar_sj0243/nustar_products/out90302319004/products/phase_resolved
# fitting done
# skipping errors for: []
#     18     0.967184     0.975809    (-0.00430281,0.00432166)
#     11      1.14128      1.19864    (-0.0290747,0.0282859)
#     14      15.1708       16.192    (-0.497773,0.523423)
#     15     0.204114     0.234568    (-0.0150513,0.0154023)
#     17     0.400555     0.423248    (-0.0112385,0.0114545)
# Fit done;  chi2 = 1406.9788700126508 for 1313 dof, chi2_red = 1.0715756816547226, H0 prob = 0.03554906107
# <Storage with 2 containers>
# ##################### bin number 4 #####################
# deleted xspec/relxilllp/*90302319004_bin4_relxilllp* and xspec/relxilllp/xcm/*90302319004_bin4_relxilllp* files
# no storage found. fitting...
#  loaded phase_resolved_bin4A_sr.pi and phase_resolved_bin4B_sr.pi from /Users/sdbykov/work/xray_pulsars/nustar_sj0243/nustar_products/out90302319004/products/phase_resolved
# fitting done
# skipping errors for: []
#     18     0.964903       0.9737    (-0.00438861,0.00440827)
#     11     0.905344     0.996694    (-0.0460869,0.0452625)
#     14      13.2008      14.1856    (-0.478605,0.506168)
# Fit done;  chi2 = 1360.7231740497573 for 1293 dof, chi2_red = 1.0523767780740583, H0 prob = 0.09304419854
#     15     0.305157     0.344126    (-0.0192165,0.019752)
#     17     0.234796     0.250169    (-0.00755115,0.00782264)
# <Storage with 2 containers>
# ##################### bin number 5 #####################
# deleted xspec/relxilllp/*90302319004_bin5_relxilllp* and xspec/relxilllp/xcm/*90302319004_bin5_relxilllp* files
# no storage found. fitting...
#  loaded phase_resolved_bin5A_sr.pi and phase_resolved_bin5B_sr.pi from /Users/sdbykov/work/xray_pulsars/nustar_sj0243/nustar_products/out90302319004/products/phase_resolved
# fitting done
# skipping errors for: []
#     18     0.966807     0.975381    (-0.00427724,0.004296)
#     11       1.3295      1.36369    (-0.0171147,0.0170777)
#     14      20.6831      21.8579    (-0.57496,0.599905)
#     15     0.148843     0.171572    (-0.0112121,0.0115167)
#     17     0.545198     0.569414    (-0.0119852,0.0122302)
# Fit done;  chi2 = 1410.098904768767 for 1375 dof, chi2_red = 1.0255264761954668, H0 prob = 0.2493982492
# <Storage with 2 containers>
# ##################### bin number 6 #####################
# deleted xspec/relxilllp/*90302319004_bin6_relxilllp* and xspec/relxilllp/xcm/*90302319004_bin6_relxilllp* files
# no storage found. fitting...
#  loaded phase_resolved_bin6A_sr.pi and phase_resolved_bin6B_sr.pi from /Users/sdbykov/work/xray_pulsars/nustar_sj0243/nustar_products/out90302319004/products/phase_resolved
# fitting done
# skipping errors for: []
#     18     0.961446     0.969843    (-0.00418955,0.00420759)
#     11      1.45882      1.49113    (-0.0161955,0.0161152)
#     14         27.3      29.1261    (-0.888357,0.937796)
#     15     0.100997     0.118942    (-0.00889592,0.00904969)
#     17     0.972622       1.0138    (-0.0203455,0.0208365)
# Fit done;  chi2 = 1374.2333440022753 for 1440 dof, chi2_red = 0.9543287111126912, H0 prob = 0.8910606152
# <Storage with 2 containers>
# ##################### bin number 7 #####################
# deleted xspec/relxilllp/*90302319004_bin7_relxilllp* and xspec/relxilllp/xcm/*90302319004_bin7_relxilllp* files
# no storage found. fitting...
#  loaded phase_resolved_bin7A_sr.pi and phase_resolved_bin7B_sr.pi from /Users/sdbykov/work/xray_pulsars/nustar_sj0243/nustar_products/out90302319004/products/phase_resolved
# fitting done
# skipping errors for: []
#     18     0.961264      0.96965    (-0.00418419,0.00420215)
#     11      1.42853      1.46075    (-0.0161499,0.0160628)
# Fit done;  chi2 = 1542.8365626006503 for 1480 dof, chi2_red = 1.0424571368923312, H0 prob = 0.1248212794
#     14      29.1522      31.1572    (-0.974473,1.03052)
#     15     0.102723     0.120814    (-0.00897135,0.00912003)
#     17     0.969659      1.01001    (-0.0199413,0.0204148)
# <Storage with 2 containers>
# ##################### bin number 8 #####################
# deleted xspec/relxilllp/*90302319004_bin8_relxilllp* and xspec/relxilllp/xcm/*90302319004_bin8_relxilllp* files
# no storage found. fitting...
#  loaded phase_resolved_bin8A_sr.pi and phase_resolved_bin8B_sr.pi from /Users/sdbykov/work/xray_pulsars/nustar_sj0243/nustar_products/out90302319004/products/phase_resolved
# fitting done
# skipping errors for: []
#     18     0.967541     0.976101    (-0.00427082,0.00428946)
#     11      1.21774      1.25246    (-0.0173988,0.0173231)
#     14      22.8384      24.1602    (-0.645862,0.675915)
# Fit done;  chi2 = 1593.358113438796 for 1452 dof, chi2_red = 1.0973540726162507, H0 prob = 0.00531206315
#     15     0.154958     0.178748    (-0.0117414,0.0120484)
#     17       0.5031     0.524972    (-0.0108365,0.0110357)
# <Storage with 2 containers>
# ##################### bin number 9 #####################
# deleted xspec/relxilllp/*90302319004_bin9_relxilllp* and xspec/relxilllp/xcm/*90302319004_bin9_relxilllp* files
# no storage found. fitting...
#  loaded phase_resolved_bin9A_sr.pi and phase_resolved_bin9B_sr.pi from /Users/sdbykov/work/xray_pulsars/nustar_sj0243/nustar_products/out90302319004/products/phase_resolved
# fitting done
# skipping errors for: []
#     18     0.968282     0.977166    (-0.0044322,0.00445174)
#     11     0.489843      0.59322    (-0.0523171,0.0510599)
#     14      11.1863      11.9652    (-0.380531,0.398344)
#     15     0.323459     0.361432    (-0.018853,0.0191199)
#     17     0.164339        0.174    (-0.00475731,0.00490421)
# Fit done;  chi2 = 1463.7491277824538 for 1319 dof, chi2_red = 1.1097415676895026, H0 prob = 0.003127066202
# <Storage with 2 containers>
# ##################### bin number 10 #####################
# deleted xspec/relxilllp/*90302319004_bin10_relxilllp* and xspec/relxilllp/xcm/*90302319004_bin10_relxilllp* files
# no storage found. fitting...
#  loaded phase_resolved_bin10A_sr.pi and phase_resolved_bin10B_sr.pi from /Users/sdbykov/work/xray_pulsars/nustar_sj0243/nustar_products/out90302319004/products/phase_resolved
# fitting done
# skipping errors for: []
#     18     0.965429      0.97424    (-0.00439577,0.00441536)
#     11     0.934317      1.02206    (-0.0449131,0.0428284)
#     14      13.9711      15.0775    (-0.528069,0.578316)
#     15     0.258161     0.294809    (-0.0181565,0.0184915)
#     17     0.234275      0.24994    (-0.00750151,0.00816301)
# Fit done;  chi2 = 1390.9299723612703 for 1306 dof, chi2_red = 1.0650306067084765, H0 prob = 0.05049798812
# <Storage with 2 containers>

# %% [markdown]
# ## Plot  phase-resolved results

# %% [markdown]
# 1. Run the following cells to plot the results.

# %%
df_ph_res = scan_containers_ph_res(model_name)
df_ph_res
# Out:
#                      error_l  error_u  frozen      val
# comp      par phase
# bbodyrad  kT  0.05       0.0      0.0     1.0  1.20421
#               0.15       0.0      0.0     1.0  1.20421
#               0.25       0.0      0.0     1.0  1.20421
#               0.35       0.0      0.0     1.0  1.20421
#               0.45       0.0      0.0     1.0  1.20421
# ...                      ...      ...     ...      ...
# relxilllp z   0.55       0.0      0.0     1.0  0.00000
#               0.65       0.0      0.0     1.0  0.00000
#               0.75       0.0      0.0     1.0  0.00000
#               0.85       0.0      0.0     1.0  0.00000
#               0.95       0.0      0.0     1.0  0.00000
#
# [160 rows x 4 columns]

# %%
df_ph_res.loc[pd.IndexSlice['relxilllp','refl_frac',:]]
# Out:
#         error_l   error_u  frozen       val
# phase
# 0.05   0.114328  0.134354     0.0  0.124228
# 0.15   0.111061  0.130004     0.0  0.120224
# 0.25   0.204114  0.234568     0.0  0.219165
# 0.35   0.305157  0.344126     0.0  0.324374
# 0.45   0.148843  0.171572     0.0  0.160055
# 0.55   0.100997  0.118942     0.0  0.109893
# 0.65   0.102723  0.120814     0.0  0.111694
# 0.75   0.154958  0.178748     0.0  0.166700
# 0.85   0.323459  0.361432     0.0  0.342312
# 0.95   0.258161  0.294809     0.0  0.276318

# %%
os.chdir(ph_res_folder)
plot_ph_res_storage(df_ph_res, nu_obs, 'phase_resolved');

# %% [markdown]
# With `df_ph_res` data frame and functions used above  you can visualize the results and creates plots and tables.
